# %%
student = {
    "name": "Manisha Thapa",
    "age": 20,
    "roll_number": 15,
    "course": "Computer Science",
    "grades": {
        "Math": 85,
        "Python": 90,
        "Data Structures": 88
    }
}

print(student)
del student.get("grades")["Math"]
student
# Out:
# {'name': 'Manisha Thapa', 'age': 20, 'roll_number': 15, 'course': 'Computer Science', 'grades': {'Math': 85, 'Python': 90, 'Data Structures': 88}}
# {'name': 'Manisha Thapa',
#  'age': 20,
#  'roll_number': 15,
#  'course': 'Computer Science',
#  'grades': {'Python': 90, 'Data Structures': 88}}

# %%
#1. What are Sets?
# Sets are unordered collections of unique, immutable elements.
#*   They do not store duplicate elements.
#   Elements must be immutable (like keys in dictionaries).
 #  Sets themselves are mutable (you can add/remove elements).
 # There is no concept of order or index.
   #Very efficient for membership testing (`in`) and removing duplicates.
print("3")
# Out:
# 3

# %%
numbers = {1, 2, 3, 4, 4, 5, 2}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}
