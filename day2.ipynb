# %%
print("Manisha")
# Out:
# Manisha

# %%
### About jupyter notebook
""Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically type-checked and garbage-collected.
Source: 
Wikipedia""

# %%
y=5
type(y)
# Out:
# int

# %%
y="5"
type(y)
# Out:
# str

# %%
x=4
y=3
print(x+y)
# Out:
# 7

# %%
y=5
y=str(y)
print(type(y))
# Out:
# <class 'str'>

# %%
age=input("enter your age")
# Out:
# enter your name maniha

# %%
age=input("enter your age")
# Out:
# enter your age 5

# %%
type(age)
# Out:
# str

# %%
age=int(input("enter the age"))
# Out:
# enter the age 5

# %%
type(age)
# Out:
# int

# %%
var1=6
var2=6.5
print(var1+var2)
# Out:
# 12.5

# %%
name="Manisha"
surname="Thapa"
age=22

# %%
#fstring
print(f"my name is {name} and surname is {surname}")
# Out:
# my name is Manisha and surname is Thapa

# %%
print("my name is",name,"surname is ",surname)
# Out:
# my name is Manisha surname is  Thapa

# %%
# dot format
print("my name {} {}".format(name,surname))
print("my name is {} {}".format("tara","thapa"))
# Out:
# my name Manisha Thapa
# my name is tara thapa

# %%
z=1j
type(z)
# Out:
# complex

# %%
is_student=True
type(is_student)
# Out:
# bool

# %%
b="namaste"
a="hello "
a+b
# Out:
# 'hello namaste'

# %%
a = "55"
b = "3"

c = a + b
print(c)
# Out:
# 553

# %%
query=input("enter you preferred course")
# Out:
# enter you preferred course datascience

# %%
type(query)
# Out:
# str

# %%
# Rules for Python variables:

### ->Cannot be any of the Python keywords.
### ->Cannot start with a number
### ->Start with a letter or the underscore character
### ->Can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
### ->Case-sensitive (age, Age and AGE are three different variables)

# %%
#legal format for words more than 1
camel case
threeDifferentVariables


pascal case
AreThreeDifferent


snake case

are_three_different

# %%
## Assign multi value
a, b = 3, 4

# %%
a, b = 3, 4
temp = 3
b = temp
b = a
a, b = b, a

# %%
a
# Out:
# 4

# %%
a,b=3,4
a,b=b,a

# %%
a
# Out:
# 4

# %%
#multiple assignment
x=y=z="bird"
a
# Out:
# 4

# %%
x
# Out:
# 'bird'

# %%
result=5>9
result
# Out:
# False

# %%
type(result)
# Out:
# bool
