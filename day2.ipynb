# %%
print("Manisha")
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/manis/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
### About jupyter notebook
""Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically type-checked and garbage-collected.
Source: 
Wikipedia""

# %%
y=5
type(y)

# %%
y="5"
type(y)

# %%
x=4
y=3
print(x+y)

# %%
y=5
y=str(y)
print(type(y))

# %%
age=input("enter your age")

# %%
age=input("enter your age")

# %%
type(age)

# %%
age=int(input("enter the age"))

# %%
type(age)

# %%
var1=6
var2=6.5
print(var1+var2)

# %%
name="Manisha"
surname="Thapa"
age=22

# %%
#fstring
print(f"my name is {name} and surname is {surname}")

# %%
print("my name is",name,"surname is ",surname)

# %%
# dot format
print("my name {} {}".format(name,surname))
print("my name is {} {}".format("tara","thapa"))

# %%
z=1j
type(z)

# %%
is_student=True
type(is_student)

# %%
b="namaste"
a="hello "
a+b

# %%
a = "55"
b = "3"

c = a + b
print(c)

# %%
query=input("enter you preferred course")

# %%
type(query)

# %%
# Rules for Python variables:

### ->Cannot be any of the Python keywords.
### ->Cannot start with a number
### ->Start with a letter or the underscore character
### ->Can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
### ->Case-sensitive (age, Age and AGE are three different variables)

# %%
#legal format for words more than 1
camel case
threeDifferentVariables


pascal case
AreThreeDifferent


snake case

are_three_different

# %%
## Assign multi value
a, b = 3, 4

# %%
a, b = 3, 4
temp = 3
b = temp
b = a
a, b = b, a

# %%
a

# %%
a,b=3,4
a,b=b,a

# %%
a

# %%
#multiple assignment
x=y=z="bird"
a

# %%
x

# %%
result=5>9
result

# %%
type(result)

# %%
name="Manisha Thapa"
print(type(name))
